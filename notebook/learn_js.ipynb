// %% [markdown]
// ## learn js

// %% [markdown]
// ## js is weird

// %%
true + false == 1;
// Out:
// true

// %%
j[,,,].length == 3 // apparently "holes", but ye valid
// Out:
// Expression expected at file:///repl.tsx:1:3
//
//   j[,,,].length == 3 // apparently "holes", but ye valid
//     ~: Expression expected at file:///repl.tsx:1:3
//
//   j[,,,].length == 3 // apparently "holes", but ye valid
//     ~

// %%
[1, 2, 3] + [4, 5, 6] == "1,2,34,5,6";
// Out:
// true

// %%
(0.1 + 0.2) === 0.3 == false;
// Out:
// true

// %%
10, 2 == 2;
// Out:
// true

// %%
!!"" == false;
// Out:
// true

// %%
+!![] == 1;
// Out:
// true

// %%
parseInt(0.0000005) == 5;
// Out:
// true

// %%
(true == "true") == false;
// Out:
// true

// %%
0o10 - 0o3 == 5;
// Out:
// true

// %%
"" - -"" == 0;
// Out:
// true

// %%
null + 0 == 0;
// Out:
// true

// %%
Number.isNaN(0 / 0);
// Out:
// true

// %%
1 / 0 > 10 ** 1000 == false;
// Out:
// true

// %%
true++;
// Out:
// The left-hand side of an assignment expression must be a variable or a property access. at file:///repl.tsx:1:1
//
//   true++
//   ~~~~: The left-hand side of an assignment expression must be a variable or a property access. at file:///repl.tsx:1:1
//
//   true++
//   ~~~~

// %%
"" - 1 == -1;
// Out:
// true

// %%
(null - 0) + "0" == "00";
// Out:
// true

// %%
Number.isNaN(true + ("true" - 0));
// Out:
// true

// %%
!5 + !5 == 0;
// Out:
// true

// %%
[] + [] == "";
// Out:
// true

// %%
1 + 2 + "3" == "33";
// Out:
// true

// %%
typeof NaN == "number";
// Out:
// true

// %%
Number.isNaN(undefined + false);
// Out:
// true

// %%
("" && -0) == ""
// Out:
// true

// %%
+!!NaN * "" - -[,] == 0;
// Out:
// true

// %%
Number.parseInt(0.0000005) == 5;
// console.log++;
// console.log += 232497;
// console.log("hello")
console.error++;
console.error--;

// console.error("hello")

// NaN(1)

let foo = 1;
foo = null;
foo++;
// undefined++
// NaN++
// null++

typeof null
typeof undefined
// Out:
// "undefined"

// %% [markdown]
// ## prototypes

// %%
const dog = {};
dog.name = "Marty";
dog.age = 12;

dog.name;
dog.breed;
// Object.setPrototypeOf(dog, Object.prototype);
// Object.setPrototypeOf(dog, null);
// dog.toString()

const p1 = Object.getPrototypeOf(dog);

const p2 = Object.getPrototypeOf(p1);
p2
Object.getPrototypeOf(Object.create(dog))
// Out:
// { name: "Marty", age: 12 }

// %% [markdown]
// ## js needed before react
